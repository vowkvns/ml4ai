# %% [markdown]
# <a href="https://colab.research.google.com/github/vowkvns/ml4ai/blob/main/week2/practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Hands-On-Data-Analysis-with-Pandas-2nd-edition/ch_02/
# Out:
# /content/drive/MyDrive/Hands-On-Data-Analysis-with-Pandas-2nd-edition/ch_02

# %%
import pandas as pd
df1=pd.DataFrame({'Name':['김상욱','박지후', '류혜영','유지원','송민주'],
                  'Major':['응통','응통','영문','심리','경영'],
                  'Nationality':['한국','한국','한국','한국','한국']})
df1
# Out:
#   Name Major Nationality
# 0  김상욱    응통          한국
# 1  박지후    응통          한국
# 2  류혜영    영문          한국
# 3  유지원    심리          한국
# 4  송민주    경영          한국

# %%
df1.index=['1번','2번','3번','4번','5번']
df1
# Out:
#    Name Major Nationality
# 1번  김상욱    응통          한국
# 2번  박지후    응통          한국
# 3번  류혜영    영문          한국
# 4번  유지원    심리          한국
# 5번  송민주    경영          한국

# %%
file_path='df1.csv'
df1.to_csv(file_path,index=False)

# %%
df2=pd.read_csv('df1.csv')
df2
# Out:
#   Name Major Nationality
# 0  김상욱    응통          한국
# 1  박지후    응통          한국
# 2  류혜영    영문          한국
# 3  유지원    심리          한국
# 4  송민주    경영          한국
