# %% [markdown]
# <a href="https://colab.research.google.com/github/vowkvns/ml4ai/blob/main/week3/practice3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/Hands-On-Data-Analysis-with-Pandas-2nd-edition/ch_02/
# Out:
# /content/drive/MyDrive/Hands-On-Data-Analysis-with-Pandas-2nd-edition/ch_02

# %%
import pandas as pd

df = pd.read_csv('data/earthquakes.csv')

# %%
df.loc[3:10, ['mag','type','magType']]
# Out:
#      mag        type magType
# 3   0.44  earthquake      ml
# 4   2.16  earthquake      md
# 5   2.61  earthquake      md
# 6   1.70  earthquake      ml
# 7   1.13  earthquake      md
# 8   0.92  earthquake      md
# 9   4.70  earthquake      mb
# 10  0.50  earthquake      ml

# %%
df.columns.get_loc('mag')
# Out:
# 8

# %%
df.columns.get_loc('magType')
# Out:
# 9

# %%
df.columns.get_loc('type')
# Out:
# 21

# %%
df.iloc[3:11, [8,9,21]]
# Out:
#      mag magType        type
# 3   0.44      ml  earthquake
# 4   2.16      md  earthquake
# 5   2.61      md  earthquake
# 6   1.70      ml  earthquake
# 7   1.13      md  earthquake
# 8   0.92      md  earthquake
# 9   4.70      mb  earthquake
# 10  0.50      ml  earthquake

# %%
df.loc[
    (df.place.str.contains('Arizona')),
    ['alert', 'mag', 'magType', 'title', 'tsunami', 'type']
]
# Out:
#      alert   mag magType                                      title  tsunami  \
# 1062   NaN  1.23      ml  M 1.2 - 7km SSW of Colorado City, Arizona        0
# 3965   NaN  0.94      md  M 0.9 - 7km WSW of Colorado City, Arizona        0
#
#             type
# 1062  earthquake
# 3965  earthquake

# %%
df1=df.sort_values(by='mag', ascending=False).head(10)

# %%
df2 = df1[ ['alert', 'mag', 'magType', 'title', 'tsunami', 'type']]

# %%
df2
# Out:
#       alert  mag magType                                        title  \
# 5263    red  7.5     mww            M 7.5 - 78km N of Palu, Indonesia
# 837   green  7.0     mww   M 7.0 - 117km E of Kimbe, Papua New Guinea
# 4363  green  6.7     mww       M 6.7 - 263km NNE of Ndoi Island, Fiji
# 118   green  6.7     mww      M 6.7 - 262km NW of Ozernovskiy, Russia
# 799   green  6.5     mww   M 6.5 - 148km S of Severo-Kuril'sk, Russia
# 816   green  6.2     mww  M 6.2 - 94km SW of Kokopo, Papua New Guinea
# 838   green  6.1      mb   M 6.1 - 132km E of Kimbe, Papua New Guinea
# 5323  green  6.1     mww          M 6.1 - 55km NNW of Palu, Indonesia
# 9211  green  6.0     mww               M 6.0 - Southwest Indian Ridge
# 862   green  6.0     mww   M 6.0 - 39km NNE of Sumberanyar, Indonesia
#
#       tsunami        type
# 5263        1  earthquake
# 837         1  earthquake
# 4363        1  earthquake
# 118         1  earthquake
# 799         1  earthquake
# 816         1  earthquake
# ...

# %%
del df2['alert']

# %%
df2.columns
# Out:
# Index(['mag', 'magType', 'title', 'tsunami', 'type'], dtype='object')

# %%
magpop = df.pop('mag')
magpop
# Out:
# 0       1.35
# 1       1.29
# 2       3.42
# 3       0.44
# 4       2.16
#         ...
# 9327    0.62
# 9328    1.00
# 9329    2.40
# 9330    1.10
# 9331    0.66
# Name: mag, Length: 9332, dtype: float64

# %%
magTypepop = df.pop('magType')
magTypepop
# Out:
# 0       ml
# 1       ml
# 2       ml
# 3       ml
# 4       md
#         ..
# 9327    md
# 9328    ml
# 9329    md
# 9330    ml
# 9331    ml
# Name: magType, Length: 9332, dtype: object

# %%
popdf = pd.concat([magpop, magTypepop], axis=1)
popdf
# Out:
#        mag magType
# 0     1.35      ml
# 1     1.29      ml
# 2     3.42      ml
# 3     0.44      ml
# 4     2.16      md
# ...    ...     ...
# 9327  0.62      md
# 9328  1.00      ml
# 9329  2.40      md
# 9330  1.10      ml
# 9331  0.66      ml
#
# [9332 rows x 2 columns]
